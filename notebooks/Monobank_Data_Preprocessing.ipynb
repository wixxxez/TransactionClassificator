# %%
import pandas as pd
import json
from datetime import datetime

# %%
mono_df = pd.read_json("../data/MonobankTransactionHistory.json")

# %%
mono_df['type'] = mono_df['amount'].apply(lambda x:  'income' if int(x) > 0 else 'outcome')
mono_df['amount'] = mono_df['amount'].apply(lambda x:  abs(int(str(x)[:-2])) )
mono_df
# Out:
#                              id        time        description   mcc  \
# 0            X2L4UyGbf3mHQnmHCg  1736016367        Анатолій К.  4829
# 1          dqY1XO0j5LgB88i-DUL2  1735950685              Glovo  4215
# 2   6cexPC-Cv8T6zid9SkR7vBBmR7M  1735950685  Скасування. Glovo  4215
# 3            5fRWZpgp0bXROL-_vA  1735920286              Glovo  4215
# 4            GGq88fUZiC3i_Vs1Mg  1735905497                EVA  5977
# ..                          ...         ...                ...   ...
# 72           X-vyOwhc3BZ6WSgrhQ  1733420561              Glovo  4215
# 73           XJ-v1Ex5uzoQImm2KA  1733391988   Magazin Smmarket  5499
# 74           B7l77oKWFSlNlbah0A  1733385157     410232****6401  4829
# 75           QOCejQDG7JN0VxnxxA  1733358644              Glovo  4215
# 76  LQPmUY6565lKDypTtCkbOsSeJx0  1733358644  Скасування. Glovo  4215
#
#     originalMcc  amount  operationAmount  currencyCode  commissionRate  \
# 0          4829     715           -71500           980               0
# 1          5499     291           -29131           980               0
# 2          5499     288            28895           980               0
# 3          5499     521           -52195           980               0
# 4          5977     671           -67100           980               0
# ..          ...     ...              ...           ...             ...
# 72         5499     618           -61830           980               0
# 73         5499     144           -14400           980               0
# 74         4829     200           -20000           980               0
# 75         5499     605           -60558           980               0
# 76         5499     599            59991           980               0
#
#     cashbackAmount  balance   hold            receiptId     type
# 0                0  1502984  False  T0E9-MC6C-3P2P-A72C  outcome
# 1                0  1574484   True                  NaN  outcome
# 2                0  1603615  False                  NaN   income
# 3                0  1574720  False  1914-H328-TBHP-KPTP  outcome
# 4                0  1626915  False  49PX-MK5B-H506-XAC1  outcome
# ..             ...      ...    ...                  ...      ...
# 72               0  1399573  False  X061-2BCB-8X53-824X  outcome
# 73               0  1461403  False  788K-M68A-BX47-59HM  outcome
# 74               0  1475803  False  2BPB-518T-K773-453X  outcome
# 75               0  1495803   True                  NaN  outcome
# 76               0  1556361  False                  NaN   income
#
# [77 rows x 14 columns]

# %%
mono_df.query('full_date == "04.01.2025"')
# Out:
#                             id        time        description   mcc  \
# 0           X2L4UyGbf3mHQnmHCg  1736016367        Анатолій К.  4829
# 1         dqY1XO0j5LgB88i-DUL2  1735950685              Glovo  4215
# 2  6cexPC-Cv8T6zid9SkR7vBBmR7M  1735950685  Скасування. Glovo  4215
#
#    originalMcc  amount  operationAmount  currencyCode  commissionRate  \
# 0         4829     715           -71500           980               0
# 1         5499     291           -29131           980               0
# 2         5499     288            28895           980               0
#
#    cashbackAmount  balance   hold            receiptId     type   full_date  \
# 0               0  1502984  False  T0E9-MC6C-3P2P-A72C  outcome  04.01.2025
# 1               0  1574484   True                  NaN  outcome  04.01.2025
# 2               0  1603615  False                  NaN   income  04.01.2025
#
#    month_number  week_number
# 0             1            1
# 1             1            1
# 2             1            1

# %%
# Extract full date, month number, and week number
mono_df['full_date'] = mono_df['time'].apply( lambda x : datetime.fromtimestamp(x).strftime("%d.%m.%Y")) 
mono_df["month_number"] =  mono_df['time'].apply( lambda x : datetime.fromtimestamp(x).month) 
mono_df["week_number"] = mono_df['time'].apply( lambda x : datetime.fromtimestamp(x).isocalendar()[1])

# %%
mono_df.to_csv("../data/MonobankTransactionHistory_IRA.csv")
